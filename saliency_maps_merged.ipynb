# %%
import rasterio as rio
from rasterio.plot import show

# %%
file = rio.open("Output/saliency_maps/gradCAM_mask_sent/gradCAM_mask_merged.tif")

# %%
file.read().shape
# Out:
# (16, 22229, 35234)

# %%
show(file.read()[15])
# Out:
# <AxesSubplot: >
